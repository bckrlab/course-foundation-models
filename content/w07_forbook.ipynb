# %% [markdown]
# # Single Cell Foundation Models II

# %% [markdown]
# ## scGPT

# %% [markdown]
# 1. How are gene expressions tokenised in scGPT, how is a cell fed into the model? And how does scGPT represent expression values in contrast to Geneformer from last week?

# %% [markdown]
# 2. What is the pre-training objective?

# %% [markdown]
# 3. What type of transformer does scGPT use?

# %% [markdown]
# 4. For scGPT, what kind of embeddings are available for downstream tasks?

# %% [markdown]
# ## TABULA

# %% [markdown]
# 1. How are gene expressions tokenised in TABULA, how is a cell fed into the model? Why does TABULA avoid imposing an ordering on genes?

# %% [markdown]
# 2. What are the two main components of the pre-training objective and what purpose does each have? How is the expression table perturbed during pre-training?

# %% [markdown]
# 3. What type of transformer does TABULA use? Is the attention of TABULA calculated row-wise, column-wise or both?

# %% [markdown]
# 4. For TABULA, what kind of embeddings are available for downstream tasks?

# %% [markdown]
# 5. Compare the transformer of TABULA to the architectures discussed in the lectures on tabular foundation models? How are they similar? What are differences?

# %% [markdown]
# ## Nicheformer

# %% [markdown]
# 1. What are the two data modalities Nicheformer is trained on, and what are the key challenges in combining them?

# %% [markdown]
# 2. Recall the definition of a *niche* in the context of cellular biology and explain how it is used in Nicheformer's downstream tasks.

# %% [markdown]
# 3. We've now seen multiple models that learn powerful cell embeddings, clustering cells cleanly by type. Reflecting on today's lecture: why are such "good embeddings" not the whole story? In your answer, touch on (a) why clustering cells well does not guarantee the model has learned causal or transferable biology, and (b) what is missing when we treat a cell as just its transcriptome.

# %% [markdown]
# ## What is a Perturbation?

# %% [markdown]
# 1. In the context of single-cell biology, what is a *perturbation*? Give two concrete examples.

# %% [markdown]
# 2. What is the goal of *in-silico perturbation prediction*, and why is it valuable compared to running perturbation experiments in the lab?

# %% [markdown]
# 3. In a perturbation experiment profiled with scRNA-seq, what is the typical structure of the data, and what is the key quantity of interest?
