# %% [markdown]
# # Tabular Foundation Models I

# %% [markdown]
# ## Neural networks on tabular data
#
# 1. What difficulties are we confronted with in the tabular data domain which we did not encounter in the visual or language domain? Give at least three examples.

# %% [markdown]
# 2. Tabular foundation models like TabPFN or TabICL use synthetic datasets to train on. Why don't they simply use real-world datasets?

# %% [markdown]
# ## TabPFN

# %% [markdown]
# 1. TabPFN as a Bayesian approach learns to approximate a conditional probability distribution. State the probability density TabPFN approximates and define all variables used.

# %% [markdown]
# Compare the TabPFN architecture to the standard Transformer introduced in previous lectures:

# %% [markdown]
# 2. The standard transformer has an encoder and a decoder block. How is the TabPFN architecture best described?
#     * Encoder-only
#     * Decoder-only
#     * Encoder-Decoder
#
#     Justify your answer and describe which parts of the architecture you would associate with the encoder/decoder.

# %% [markdown]
# 3. In the standard Transformer, discrete tokens are first embedded into a latent space (with a learnt embedding) and then a positional encoding is added. How are inputs processed in TabPFNv2?
# What components do the transformer layers of the TabPFNv2 architecture consist of?
#
#     Since the input processing is one of the major differences between TabPFNv1 and TabPFNv2, describe what was changed. In particular, what does a token represent in each architecture?

# %% [markdown]
# 4. Consider the application of a TabPFNv2 transformer layer to a dataset with $n$ samples (i.e. rows), each with $d$ features (i.e. columns). Of the $n$ samples, $n_\mathrm{test}$ are test samples.
# How many "passes" through the model are needed to generate the model predictions? What is the asymptotic complexity of the self-attention layers of TabPFNv2?

# %% [markdown]
# 5. Are the generated labels of the TabPFN model (either v1 or v2) dependent on the order of the training set or the test set? In particular, are the test labels generated independently of each other? Justify your answer.

# %% [markdown]
# # Homework

# %% [markdown]
# 1. Finish this exercise sheet and review the solutions! The sheets are not graded but solving them helps *a lot* to prepare for the exam. We provide solutions to the exercises on Ilias. Write your own solutions down FIRST (best by hand!) and review our solutions only AFTER you finished the exercises.
# 2. Read [TabPFNv2, Hollmann et al. 2025](https://www.nature.com/articles/s41586-024-08328-6), the second iteration on the TabPFN architecture.
# 3. Read [TabICL: A Tabular Foundation Model for In-Context Learning on Large Data, Qu et al. 2025](https://arxiv.org/abs/2502.05564) and optionally also [TabICLv2, Qu et al. 2026](https://arxiv.org/abs/2602.11139)
