# %% [markdown]
# # Single Cell Foundation Models I

# %% [markdown]
# ## Foundation Models in the Single-Cell Domain

# %% [markdown]
# 1. What does single-cell RNA-seq (*scRNA-seq*) data measure, and how does it differ from *bulk RNA-seq* data?

# %% [markdown]
# 2. Very briefly describe how scRNA-seq data is generated experimentally. What are the key steps from tissue to count matrix?

# %% [markdown]
# 3. scRNA-seq data is often described as "sparse". What causes this sparsity, and why does it pose a challenge?

# %% [markdown]
# 4. Name and briefly explain at least two typical preprocessing steps applied to raw scRNA-seq count matrices.

# %% [markdown]
# 5. Name and briefly describe at least three downstream tasks that a single-cell foundation model can be applied to after pre-training.

# %% [markdown]
# 6. What makes it difficult to evaluate the quality of representations learned by a single-cell foundation model, compared to evaluating a model in standard NLP or vision tasks?

# %% [markdown]
# ## Geneformer

# %% [markdown]
# 1. How are gene expressions tokenised in the Geneformer, how is a cell fed into the model?

# %% [markdown]
# 2. Think of some potential advantages and disadvantages of this approach to representing gene expression values.

# %% [markdown]
# 3. What is the pre-training objective?

# %% [markdown]
# 4. What type of transformer does Geneformer use?

# %% [markdown]
# 5. For Geneformer, what kind of embeddings are available for downstream tasks?
